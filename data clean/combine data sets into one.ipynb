# %%
import pandas as pd
bicycle = pd.read_csv("bicycle_injury.csv")# read 
bicycle.head()
# Out:
#     ACCIDENT_NO SEX  AGE Age Group  INJ_LEVEL Inj Level Desc  \
# 0  T20060000213   M   20     17-21          3   Other injury
# 1  T20060000431   M   20     17-21          3   Other injury
# 2  T20060000596   M   18     17-21          3   Other injury
# 3  T20060000876   M   19     17-21          3   Other injury
# 4  T20060000961   F   24     22-25          3   Other injury
#
#   Road User Type Desc  DCA Description  latitude  longitude
# 0          Bicyclists              NaN       NaN        NaN
# 1          Bicyclists              NaN       NaN        NaN
# 2          Bicyclists              NaN       NaN        NaN
# 3          Bicyclists              NaN       NaN        NaN
# 4          Bicyclists              NaN       NaN        NaN

# %%
bicycle[bicycle["ACCIDENT_NO"].duplicated()]# delete duplicate data
# Out:
#        ACCIDENT_NO SEX  AGE Age Group  INJ_LEVEL  Inj Level Desc  \
# 67    T20060025422   M   23     22-25          3    Other injury
# 239   T20070029838   M   18     17-21          4     Not injured
# 301   T20080000253   M   20     17-21          3    Other injury
# 302   T20080000253   M   20     17-21          4     Not injured
# 312   T20080002730   M   21     17-21          4     Not injured
# 313   T20080002730   M   24     22-25          4     Not injured
# 462   T20080041690   F   22     22-25          3    Other injury
# 485   T20080048143   M   18     17-21          3    Other injury
# 490   T20090000858   F   18     17-21          4     Not injured
# 511   T20090006297   M   19     17-21          3    Other injury
# 515   T20090006554   M   22     22-25          3    Other injury
# 798   T20100038936   F   22     22-25          3    Other injury
# 1025  T20110041350   M   21     17-21          4     Not injured
# ...

# %%
bicycle_data=[]# append data into list 
for i in bicycle["ACCIDENT_NO"]:
    bicycle_data.append(i) 
len(bicycle_data)
# Out:
# 2237

# %%
len(set(bicycle_data))# check len
# Out:
# 2237

# %% [markdown]
# ## combine description data and bicycle data into one by accident id

# %%
Dac_discription=[]
for i in range (len(discription["ACCIDENT_NO"])):#combine data by accident id
    if discription["ACCIDENT_NO"][i] in bicycle_data:
        Dac_discription.append(discription["DCA Description"][i])
len(Dac_discription)

# %%
bicycle["DCA Description"]=Dac_discription# write list into data frame

# %%
location= pd.read_csv("location_111.csv")#read data
location.head()

# %% [markdown]
# ### combine location set and bicycle data set by accident id.

# %%
bicycle.to_csv("data.csv",index=False)# write data

# %%
data2= pd.read_csv("data2.csv")
bicycle2=[]
for i in data2["ACCIDENT_NO"]:
    bicycle2.append(i)
    
len(bicycle2)
# Out:
# 2235

# %%
location=location.drop_duplicates(["ACCIDENT_NO"])
location= location.reset_index()#reset index

# %%
lat=[]
long=[]
a=[]
Postcode=[]
for i in range (len(location["ACCIDENT_NO"])):
    if location["ACCIDENT_NO"][i] in bicycle2:
        lat.append(location["Lat"][i])
        long.append(location["Long"][i])
        Postcode.append(location["Postcode No"][i])
len(lat)
# Out:
# 2235

# %% [markdown]
# ### write lat,lon,postcode into new data sets

# %%
data2["latitude"]=lat
data2["longitude"]=long
data2["postcode"]=Postcode

# %%
data2# have a look new data sets
# Out:
#        ACCIDENT_NO SEX  AGE Age Group  INJ_LEVEL  Inj Level Desc  \
# 0     T20060000213   M   20     17-21          3    Other injury
# 1     T20060000431   M   20     17-21          3    Other injury
# 2     T20060000596   M   18     17-21          3    Other injury
# 3     T20060000876   M   19     17-21          3    Other injury
# 4     T20060000961   F   24     22-25          3    Other injury
# 5     T20060001260   M   18     17-21          3    Other injury
# 6     T20060001264   M   19     17-21          3    Other injury
# 7     T20060001366   U   24     22-25          2  Serious injury
# 8     T20060001835   F   23     22-25          3    Other injury
# 9     T20060002184   M   20     17-21          2  Serious injury
# 10    T20060002252   F   22     22-25          3    Other injury
# 11    T20060002274   M   20     17-21          2  Serious injury
# 12    T20060002455   F   22     22-25          3    Other injury
# ...

# %%
set(Dac_discription)
# Out:
# {'ANY MANOEUVRE INVOLVING PED NOT INCLUDED IN DCAs 100-108.  ',
#  'CROSS TRAFFIC(INTERSECTIONS ONLY)              ',
#  'CUTTING IN (OVERTAKING)                   ',
#  'ENTERING PARKING                      ',
#  'FAR SIDE. PED HIT BY VEHICLE FROM THE LEFT         ',
#  'FELL IN/FROM VEHICLE                    ',
#  'HEAD ON (NOT OVERTAKING)                  ',
#  'HEAD ON(OVERTAKING)                     ',
#  'LANE CHANGE LEFT (NOT OVERTAKING)              ',
#  'LANE CHANGE RIGHT (NOT OVERTAKING)             ',
#  'LANE SIDE SWIPE (VEHICLES IN PARALLEL LANES)        ',
#  'LEAVING PARKING                       ',
#  'LEFT FAR (INTERSECTIONS ONLY)                ',
#  'LEFT NEAR (INTERSECTIONS ONLY)               ',
#  'LEFT OFF CARRIAGEWAY INTO OBJECT/PARKED VEHICLE       ',
#  'LEFT REAR                          ',
#  'LEFT THROUGH                        ',
#  'LEFT TURN SIDESWIPE                     ',
#  'LEFT/RIGHT FAR (INTERSECTIONS ONLY)             ',
# ...

# %%
data2.to_csv("data3.csv",index=False)#write data set

# %% [markdown]
# #### change abbreviation to full name

# %%
for i in range (len(data["State"])):
    if data["State"][i] =="Vic":
        data["State"][i]="victoria"
    if data["State"][i] =="ACT":
        data["State"][i]="AUSTRALIA CAPITAL TERRITORY"
    if data["State"][i] =="NSW":
        data["State"][i]="NEW SOUTH WALES"
    if data["State"][i] =="NT":
        data["State"][i]="NORTHERN TERRITO"
    if data["State"][i] =="Qld":
        data["State"][i]="QUEENSLAND"
    if data["State"][i] =="SA":
        data["State"][i]="SOUTH AUSTRALIA"
    if data["State"][i] =="Tas":
        data["State"][i]="TASMANIA"
    if data["State"][i] =="WA":
        data["State"][i]="WEST AUSTRALIA"
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# ...

# %% [markdown]
# #### delete error data(no non data. if data can be found, row data shou "-9".) tip: -9 is not int. thay are recorded as string

# %%
data2=data[data["Age"]!=-9]
data3=data2[data2["Crash Type"]!="-9"]
data4=data3[data3["Bus Involvement"]!="-9"]
data5=data4[data4["Speed Limit"]!="-9"]
data6=data5[data5["Road User"]!="Other/-9"]
data7=data6[data6["Gender"]!="-9"]
data8=data7[data7["Age Group"]=="17_to_25"]
data9=data8[data8["Speed Limit"]!="<40"]

# %%
data9.dtypes#check data type
# Out:
# Crash ID                          int64
# State                            object
# Month                             int64
# Year                              int64
# Dayweek                          object
# Time                             object
# Crash Type                       object
# Bus Involvement                  object
# Heavy Rigid Truck Involvement    object
# Articulated Truck Involvement    object
# Speed Limit                      object
# Road User                        object
# Gender                           object
# Age                               int64
# National Remoteness Areas        object
# SA4 Name 2016                    object
# National LGA Name 2017           object
# National Road Type               object
# Christmas Period                 object
# Easter Period                    object
# Age Group                        object
# Day of week                      object
# Time of day                      object
# dtype: object

# %%
data9[["Speed Limit"]] = data9[["Speed Limit"]].astype(int)# change data type form string to list
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
data9.dtypes # chaeck data type again
# Out:
# Crash ID                          int64
# State                            object
# Month                             int64
# Year                              int64
# Dayweek                          object
# Time                             object
# Crash Type                       object
# Bus Involvement                  object
# Heavy Rigid Truck Involvement    object
# Articulated Truck Involvement    object
# Speed Limit                       int32
# Road User                        object
# Gender                           object
# Age                               int64
# National Remoteness Areas        object
# SA4 Name 2016                    object
# National LGA Name 2017           object
# National Road Type               object
# Christmas Period                 object
# Easter Period                    object
# Age Group                        object
# Day of week                      object
# Time of day                      object
# dtype: object

# %%
data10=data9.drop(["Bus Involvement","Heavy Rigid Truck Involvement", "Articulated Truck Involvement","SA4 Name 2016",
           "National LGA Name 2017","National Road Type","Christmas Period","Easter Period","National Remoteness Areas",
           "Crash ID"], axis=1)#drop useless daata sets

# %%
data10.to_csv("crash.csv",index=False)# write data sets

# %%
data10[(data10["State"]=="Vic")& (data10["Year"]>2010)]# have a look new data sets
# Out:
#       State  Month  Year   Dayweek   Time  Crash Type  Speed Limit  \
# 336     Vic      4  2019    Friday   2:40      Single           50
# 350     Vic      4  2019    Monday  20:11    Multiple           60
# 513     Vic      3  2019    Friday   0:55  Pedestrian           60
# 531     Vic      2  2019  Saturday  16:35    Multiple           60
# 532     Vic      2  2019  Saturday  17:24    Multiple           80
# 545     Vic      2  2019    Sunday  20:16      Single          100
# 548     Vic      2  2019    Sunday  12:00    Multiple           80
# 551     Vic      2  2019  Saturday   2:08  Pedestrian           80
# 614     Vic      1  2019  Thursday   3:00  Pedestrian           80
# 640     Vic      1  2019  Thursday  11:25      Single          110
# 655     Vic      1  2019    Sunday  21:30    Multiple          100
# 688     Vic      1  2019    Friday  21:27      Single          100
# 712     Vic      1  2019  Saturday  21:17      Single           80
# ...
