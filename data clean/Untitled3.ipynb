# %%
import pandas as pd
data=pd.read_excel("newdata_data.xlsx")
data2=pd.read_csv("ACCIDENT.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (10,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#      ACCIDENT_NO SEX  AGE Age Group  INJ_LEVEL  Inj Level Desc  \
# 0   T20060000876   M   19     17-21          3    Other injury
# 1   T20060004271   M   24     22-25          3    Other injury
# 2   T20060008093   F   20     17-21          3    Other injury
# 3   T20060028423   M   23     22-25          3    Other injury
# 4   T20060032990   M   21     17-21          3    Other injury
# 5   T20060035115   M   19     17-21          2  Serious injury
# 6   T20060036656   M   23     22-25          2  Serious injury
# 7   T20060041681   M   18     17-21          2  Serious injury
# 8   T20060046407   M   23     22-25          2  Serious injury
# 9   T20070001673   M   22     22-25          2  Serious injury
# 10  T20070037500   M   23     22-25          3    Other injury
# 11  T20070043536   M   24     22-25          3    Other injury
# 12  T20080000365   M   23     22-25          3    Other injury
# 13  T20080009102   M   19     17-21          3    Other injury
# ...

# %%
data2.head()
# Out:
#     ACCIDENT_NO ACCIDENTDATE ACCIDENTTIME  ACCIDENT_TYPE  \
# 0  T20060000010   13/01/2006     12.42.00              1
# 1  T20060000018   13/01/2006     19.10.00              1
# 2  T20060000022   14/01/2006     12.10.00              7
# 3  T20060000023   14/01/2006     11.49.00              1
# 4  T20060000026   14/01/2006     10.45.00              1
#
#                Accident Type Desc  DAY_OF_WEEK Day Week Description  DCA_CODE  \
# 0          Collision with vehicle            6               Friday       113
# 1          Collision with vehicle            6               Friday       113
# 2  Fall from or in moving vehicle            7             Saturday       190
# 3          Collision with vehicle            7             Saturday       130
# 4          Collision with vehicle            7             Saturday       121
#
#                                   DCA Description DIRECTORY     ...      \
# 0  RIGHT NEAR (INTERSECTIONS ONLY)                      MEL     ...
# ...

# %%
no=[]
desc=[]
for i in data2:
    desc.append(data2["Accident Type Desc"])
    no.append(data2["ACCIDENT_NO"])

# %%
data_no=[]
for i in data["ACCIDENT_NO"]:
    data_no.append(data["ACCIDENT_NO"])
len(data_no)
# Out:
# 84

# %%
len(desc[0])
desc[0][0]
# Out:
# 'Collision with vehicle'

# %%
len(no[0])
no[0][0]
# Out:
# 'T20060000010'

# %%
data_no[0][0]
# Out:
# 'T20060000876'

# %%
xx=[]
for i in range (len(desc[0])):
    for x in range (len(data_no[0])):
        if no[0][i]==data_no[0][x]:
            xx.append(desc[0][i])
    
xx
# Out:
# ['Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Struck Pedestrian',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
#  'Collision with vehicle',
# ...

# %%
len(xx)
data["desc"]=xx
# Out:
# 84

# %%
data.to_csv("data_desc.csv",index=False)

# %%
data_no[0][0]
# Out:
# 'T20060000876'

# %%
no[0]
# Out:
# 0         T20060000010
# 1         T20060000018
# 2         T20060000022
# 3         T20060000023
# 4         T20060000026
# 5         T20060000028
# 6         T20060000035
# 7         T20060000042
# 8         T20060000044
# 9         T20060000046
# 10        T20060000047
# 11        T20060000050
# 12        T20060000066
# 13        T20060000094
# 14        T20060000095
# 15        T20060000096
# 16        T20060000105
# 17        T20060000111
# 18        T20060000114
# 19        T20060000116
# 20        T20060000119
# 21        T20060000126
# 22        T20060000130
# 23        T20060000132
# 24        T20060000133
# 25        T20060000134
# 26        T20060000135
# 27        T20060000141
# 28        T20060000157
# 29        T20060000158
#               ...
# 181575    T20190013796
# 181576    T20190013798
# 181577    T20190013816
# 181578    T20190013827
# 181579    T20190013828
# 181580    T20190013849
# 181581    T20190013876
# 181582    T20190013877
# 181583    T20190013879
# ...

# %% [markdown]
# end

# %%
import pandas as pd
data1=pd.read_csv("data1.csv")

# %%
data1.head()
# Out:
#     ACCIDENT_NO SEX  AGE  INJ_LEVEL  Inj Level Desc Road User Type Desc  road
# 0  T20060000201   M   14          2  Serious injury          Bicyclists   NaN
# 1  T20060000202   M   42          3    Other injury          Bicyclists   NaN
# 2  T20060000213   M   20          3    Other injury          Bicyclists   NaN
# 3  T20060000286   M   29          2  Serious injury          Bicyclists   NaN
# 4  T20060000337   M   36          3    Other injury          Bicyclists   NaN

# %%
ACCIDENT_NO=[]
for i in data1["ACCIDENT_NO"]:
    ACCIDENT_NO.append(i)
len(ACCIDENT_NO)
# Out:
# 18733

# %%
data1[data1.duplicated('ACCIDENT_NO')==True]
# Out:
#         ACCIDENT_NO SEX  AGE  INJ_LEVEL  Inj Level Desc Road User Type Desc  \
# 30     T20060001633   F   12          3    Other injury          Bicyclists
# 112    T20060004608   M   52          3    Other injury          Bicyclists
# 113    T20060004608   M   43          3    Other injury          Bicyclists
# 114    T20060004608   M   51          3    Other injury          Bicyclists
# 126    T20060005169   M   49          2  Serious injury          Bicyclists
# 200    T20060007675   M   50          2  Serious injury          Bicyclists
# 201    T20060007675   M   54          2  Serious injury          Bicyclists
# 256    T20060010046   M   10          3    Other injury          Bicyclists
# 336    T20060013667   M   39          2  Serious injury          Bicyclists
# 364    T20060015815   M   37          4     Not injured          Bicyclists
# 456    T20060021751   M   48          3    Other injury          Bicyclists
# ...

# %%
data2=pd.read_csv("data2.csv")

# %%
data2.head()
# Out:
#     ACCIDENT_NO  NODE_ID  ROAD_ROUTE_1   ROAD_NAME    ROAD_NAME_INT
# 0  T20060000010    43078        2090.0      FOSTER           MCCRAE
# 1  T20060000018    29720        5057.0      HALLAM  BELGRAVE-HALLAM
# 2  T20060000022   203074        9999.0      BROWNS         TRUEMANS
# 3  T20060000023    55462        2400.0  SPRINGVALE      KEYSBOROUGH
# 4  T20060000026   202988        9999.0   ELIZABETH        GREENHOOD

# %%
road=[]
Id=[]
for i in range (len(data2)):
    if data2["ACCIDENT_NO"][i] in ACCIDENT_NO:
        road.append(data2["ROAD_NAME_INT"][i])
        Id.append(data2["ACCIDENT_NO"][i])

len(Id)
# Out:
# 18301

# %%
len(road)
# Out:
# 18301

# %%
len(set(road))
# Out:
# 4917

# %%
x=[]
for i in road:
    if i == "VICTORIA":
        x.append(i)
len(x)
# Out:
# 221

# %%
from geopy.geocoders import Nominatim
longitude=[]
latitude=[]
gps = Nominatim()
for i in road:

    
    location = gps.geocode(i)
    longitude.append(location.longitude)
    latitude.append(location.latitude)
    print(i)
    print (location.longitude,location.latitude)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   after removing the cwd from sys.path.
# FLEETWOOD
# -3.0076372 53.9246318
# WATKIN
# -93.6275819 39.6487033
# MCCULLOUGH
# -78.6152911 37.7570875
# LORNA
# -91.441331 38.914631
# STAM
# 5.2602928 52.2890357
# POUND
# -82.6012667 37.1237146
# STATION
# 99.9615397 7.0366682
# CATHERINE
# -1.3786433 48.8931602
# ---------------------------------------------------------------------------
# ...

# %%
mis=[]
for i in range (len(data1["ACCIDENT_NO"])):
    if data1["ACCIDENT_NO"][i] not in Id:
        mis.append(data1["ACCIDENT_NO"][i])
len(mis)
# Out:
# 0

# %%
a={}
for i in range (len(Id)):
    a[Id[i]]=road[i]

# %%
a
# Out:
# {'T20060000201': 'FLEETWOOD vic',
#  'T20060000202': 'WATKIN vic',
#  'T20060000213': 'MCCULLOUGH vic',
#  'T20060000286': 'LORNA vic',
#  'T20060000337': 'STAM vic',
#  'T20060000398': 'POUND vic',
#  'T20060000431': 'STATION vic',
#  'T20060000596': 'CATHERINE vic',
#  'T20060000602': 'BAY vic',
#  'T20060000614': 'YARRA vic',
#  'T20060000619': 'NEPEAN vic',
#  'T20060000625': 'FIRST vic',
#  'T20060000636': 'COBURNS vic',
#  'T20060000847': 'CHARLES vic',
#  'T20060000876': 'BROWNS vic',
#  'T20060000961': 'JOHNS vic',
#  'T20060001031': 'BENT vic',
#  'T20060001035': 'BRIDGE vic',
#  'T20060001120': 'GLENWOOD vic',
#  'T20060001128': 'SOUTH BEACH vic',
#  'T20060001138': 'ORMOND vic',
#  'T20060001160': 'CLOW ALT vic',
#  'T20060001260': 'CHURCH vic',
#  'T20060001264': 'MOSSFIEL vic',
#  'T20060001341': 'BLUFF vic',
#  'T20060001376': 'BURGESS vic',
#  'T20060001494': 'CHAPMAN vic',
#  'T20060001514': 'GRIEVE vic',
#  'T20060001543': 'PIER vic',
# ...

# %%
road
# Out:
# ['FLEETWOOD vic',
#  'WATKIN vic',
#  'MCCULLOUGH vic',
#  'LORNA vic',
#  'STAM vic',
#  'POUND vic',
#  'STATION vic',
#  'CATHERINE vic',
#  'BAY vic',
#  'YARRA vic',
#  'NEPEAN vic',
#  'FIRST vic',
#  'COBURNS vic',
#  'CHARLES vic',
#  'BROWNS vic',
#  'JOHNS vic',
#  'BENT vic',
#  'BRIDGE vic',
#  'GLENWOOD vic',
#  'SOUTH BEACH vic',
#  'ORMOND vic',
#  'CLOW ALT vic',
#  'CHURCH vic',
#  'MOSSFIEL vic',
#  'BLUFF vic',
#  'BURGESS vic',
#  'CHAPMAN vic',
#  'GRIEVE vic',
#  'PIER vic',
#  'FAIRBAIRN vic',
#  'GLYNDON vic',
#  'MALE vic',
#  'CLORIS vic',
#  'HILLSIDE vic',
#  'HEIDELBERG vic',
#  'GERTRUDE vic',
#  'HOWITT ALT vic',
#  'KEES vic',
#  'YARRA vic',
#  'BARRIES vic',
#  'WOOD vic',
#  'ISLA vic',
#  'GLADESVILLE vic',
#  'PARLIAMENT vic',
#  'DWYER vic',
#  'NARMBOOL vic',
#  'COLLINS vic',
#  'VICTORIA vic',
#  'PILKINGTON vic',
#  'ST KILDA vic',
#  'SHEARWATER vic',
#  'THERRY vic',
#  'POUND vic',
#  'WELLINGTON vic',
#  'BULL vic',
#  'ORLANDO vic',
# ...

# %%
for i in range (len(data1["ACCIDENT_NO"])):
    data1["road"][i]=a[data1["ACCIDENT_NO"][i]]
    print(data1["road"][i])
    print(data1["ACCIDENT_NO"][i])
    print(a[data1["ACCIDENT_NO"][i]])
    
data1.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# FLEETWOOD vic
# T20060000201
# FLEETWOOD vic
# WATKIN vic
# T20060000202
# WATKIN vic
# MCCULLOUGH vic
# T20060000213
# MCCULLOUGH vic
# LORNA vic
# T20060000286
# LORNA vic
# STAM vic
# T20060000337
# STAM vic
# POUND vic
# T20060000398
# POUND vic
# STATION vic
# T20060000431
# STATION vic
# CATHERINE vic
# T20060000596
# CATHERINE vic
# BAY vic
# T20060000602
# ...

# %%
len(data1["road"])
# Out:
# 18733

# %%
len(set(road))
# Out:
# 5254

# %%
data1.to_csv("dataclean.csv",index=False)
